# %% [markdown]
# <a href="https://colab.research.google.com/github/apoorvpsit123/apoorvpsit123-CS--3B/blob/main/Retail_Sales_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/SQL - Retail_Sales_Analysis_utf.csv')

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    transactions_id   sale_date sale_time  customer_id  gender   age  category  \
# 0              180  05-11-2022  10:47:00          117    Male  41.0  Clothing
# 1              522  09-07-2022  11:00:00           52    Male  46.0    Beauty
# 2              559  12-12-2022  10:48:00            5  Female  40.0  Clothing
# 3             1180  06-01-2022  08:53:00           85    Male  41.0  Clothing
# 4             1522  14-11-2022  08:35:00           48    Male  46.0    Beauty
#
#    quantiy  price_per_unit   cogs  total_sale
# 0      3.0           300.0  129.0       900.0
# 1      3.0           500.0  145.0      1500.0
# 2      4.0           300.0   84.0      1200.0
# 3      3.0           300.0  129.0       900.0
# 4      3.0           500.0  235.0      1500.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
display(df.describe(include='all'))
# Out:
#         transactions_id   sale_date sale_time  customer_id  gender  \
# count       2000.000000        2000      2000  2000.000000    2000
# unique              NaN         647       766          NaN       2
# top                 NaN  01-12-2022  21:47:00          NaN  Female
# freq                NaN          12         9          NaN    1020
# mean        1000.500000         NaN       NaN    66.341500     NaN
# std          577.494589         NaN       NaN    44.937185     NaN
# min            1.000000         NaN       NaN     1.000000     NaN
# 25%          500.750000         NaN       NaN    24.000000     NaN
# 50%         1000.500000         NaN       NaN    69.000000     NaN
# 75%         1500.250000         NaN       NaN   102.000000     NaN
# max         2000.000000         NaN       NaN   155.000000     NaN
#
#                 age  category      quantiy  price_per_unit         cogs  \
# count   1990.000000      2000  1997.000000     1997.000000  1997.000000
# ...

# %% [markdown]
# # Task
# Please provide more details on the target variable and features you'd like to use for supervised learning.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide details on the target variable and features for supervised learning.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# *   **What is the target variable for supervised learning?**
#     The target variable identified for supervised learning is `Customer_Churn`, which is a binary categorical variable indicating whether a customer has churned (1) or not (0).
#
# *   **What are the features for supervised learning?**
#     The selected features for supervised learning include a mix of numerical and categorical variables:
#     *   **Numerical Features**: `Age`, `Subscription_Duration_Months`, `Monthly_Charges`, and `Data_Usage_GB`.
#     *   **Categorical Features**: `Contract_Type`, `Payment_Method`, `Internet_Service_Type`, `Online_Security`, `Tech_Support`, and `Has_Promotional_Discount`.
#
# ### Data Analysis Key Findings
# *   The chosen target variable, `Customer_Churn`, is a binary indicator, suitable for binary classification models.
# *   A diverse set of 10 features has been selected, encompassing both demographic, usage, and service-related information, which are crucial for predicting churn.
# *   The features include four numerical variables (`Age`, `Subscription_Duration_Months`, `Monthly_Charges`, `Data_Usage_GB`) and six categorical variables (`Contract_Type`, `Payment_Method`, `Internet_Service_Type`, `Online_Security`, `Tech_Support`, `Has_Promotional_Discount`), providing a comprehensive view of customer behavior and characteristics.
#
# ### Insights or Next Steps
# *   The defined target variable and features form a solid basis for building various supervised learning models (e.g., Logistic Regression, Decision Trees, Gradient Boosting) to predict customer churn.
# *   Further steps should involve detailed feature engineering, handling of categorical variables (e.g., one-hot encoding), feature scaling for numerical variables, and then model training and evaluation.
